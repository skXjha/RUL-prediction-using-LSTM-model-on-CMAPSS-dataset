# %%
# !nvidia-smi
# Out:
# Sun Nov  9 06:35:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
file_path1 = '/content/drive/MyDrive/train_FD003.txt'

# %%
file_path2 = '/content/drive/MyDrive/test_FD003.txt'

# %%
file_path3 = '/content/drive/MyDrive/RUL_FD003.txt'

# %%
column_names=['engine', 'cycles', 'setting1', 'setting2', 'setting3', 'Total temperature at fan inlet', 'Total temperature at LPC outlet', 'Total temperature at HPC outlet', 'Total temperature at LPT outlet', 'Pressure at fan inlet', 'Total pressure in bypass-duct', 'Total pressure at HPC outlet', 'Physical fan speed', 'Physical core speed', 'Engine pressure ratio (P50/P2)', 'Static pressure at HPC outlet', 'Ratio of fuel flow to Ps30', 'Corrected fan speed', 'Corrected core speed', 'Bypass Ratio', 'Burner fuel-air ratio', 'Bleed Enthalpy', 'Demanded fan speed', 'Demanded corrected fan speed', 'HPT coolant bleed', 'LPT coolant bleed']

# %%
train3 = pd.read_csv((file_path1) , sep='\s+', header = None, names = column_names)

# %%
train3
# Out:
#        engine  cycles  setting1  setting2  setting3  \
# 0           1       1   -0.0005    0.0004     100.0
# 1           1       2    0.0008   -0.0003     100.0
# 2           1       3   -0.0014   -0.0002     100.0
# 3           1       4   -0.0020    0.0001     100.0
# 4           1       5    0.0016    0.0000     100.0
# ...       ...     ...       ...       ...       ...
# 24715     100     148   -0.0016   -0.0003     100.0
# 24716     100     149    0.0034   -0.0003     100.0
# 24717     100     150   -0.0016    0.0004     100.0
# 24718     100     151   -0.0023    0.0004     100.0
# 24719     100     152    0.0000    0.0003     100.0
#
#        Total temperature at fan inlet  Total temperature at LPC outlet  \
# 0                              518.67                           642.36
# 1                              518.67                           642.50
# 2                              518.67                           642.18
# 3                              518.67                           642.92
# 4                              518.67                           641.68
# ...                               ...                              ...
# 24715                          518.67                           643.78
# 24716                          518.67                           643.29
# 24717                          518.67                           643.84
# 24718                          518.67                           643.94
# 24719                          518.67                           643.64
#
#        Total temperature at HPC outlet  Total temperature at LPT outlet  \
# 0                              1583.23                          1396.84
# 1                              1584.69                          1396.89
# 2                              1582.35                          1405.61
# 3                              1585.61                          1392.27
# 4                              1588.63                          1397.65
# ...                                ...                              ...
# 24715                          1596.01                          1424.11
# 24716                          1596.38                          1429.14
# 24717                          1604.53                          1431.41
# 24718                          1597.56                          1426.57
# 24719                          1599.04                          1436.06
#
#        Pressure at fan inlet  ...  Ratio of fuel flow to Ps30  \
# 0                      14.62  ...                      522.31
# 1                      14.62  ...                      522.42
# 2                      14.62  ...                      522.03
# 3                      14.62  ...                      522.49
# 4                      14.62  ...                      522.58
# ...                      ...  ...                         ...
# 24715                  14.62  ...                      519.66
# 24716                  14.62  ...                      519.91
# 24717                  14.62  ...                      519.44
# 24718                  14.62  ...                      520.01
# 24719                  14.62  ...                      519.48
#
#        Corrected fan speed  Corrected core speed  Bypass Ratio  \
# 0                  2388.01               8145.32        8.4246
# 1                  2388.03               8152.85        8.4403
# 2                  2388.00               8150.17        8.3901
# 3                  2388.08               8146.56        8.3878
# 4                  2388.03               8147.80        8.3869
# ...                    ...                   ...           ...
# 24715              2388.30               8138.08        8.5036
# 24716              2388.28               8144.36        8.5174
# 24717              2388.24               8135.95        8.5223
# 24718              2388.26               8141.24        8.5148
# 24719              2388.24               8136.98        8.5150
#
#        Burner fuel-air ratio  Bleed Enthalpy  Demanded fan speed  \
# 0                       0.03             391                2388
# 1                       0.03             392                2388
# 2                       0.03             391                2388
# 3                       0.03             392                2388
# 4                       0.03             392                2388
# ...                      ...             ...                 ...
# 24715                   0.03             394                2388
# 24716                   0.03             395                2388
# 24717                   0.03             396                2388
# 24718                   0.03             395                2388
# 24719                   0.03             396                2388
#
#        Demanded corrected fan speed  HPT coolant bleed  LPT coolant bleed
# 0                             100.0              39.11            23.3537
# 1                             100.0              38.99            23.4491
# 2                             100.0              38.85            23.3669
# 3                             100.0              38.96            23.2951
# 4                             100.0              39.14            23.4583
# ...                             ...                ...                ...
# 24715                         100.0              38.44            22.9631
# 24716                         100.0              38.50            22.9746
# 24717                         100.0              38.39            23.0682
# 24718                         100.0              38.31            23.0753
# 24719                         100.0              38.56            23.0847
#
# [24720 rows x 26 columns]

# %%
test3 = pd.read_csv((file_path2) , sep='\s+', header = None, names = column_names)

# %%
test3
# Out:
#        engine  cycles  setting1  setting2  setting3  \
# 0           1       1   -0.0017   -0.0004     100.0
# 1           1       2    0.0006   -0.0002     100.0
# 2           1       3    0.0014   -0.0003     100.0
# 3           1       4    0.0027    0.0001     100.0
# 4           1       5   -0.0001    0.0001     100.0
# ...       ...     ...       ...       ...       ...
# 16591     100     243    0.0011   -0.0003     100.0
# 16592     100     244   -0.0024    0.0002     100.0
# 16593     100     245   -0.0053    0.0002     100.0
# 16594     100     246   -0.0006    0.0001     100.0
# 16595     100     247    0.0023    0.0004     100.0
#
#        Total temperature at fan inlet  Total temperature at LPC outlet  \
# 0                              518.67                           641.94
# 1                              518.67                           642.02
# 2                              518.67                           641.68
# 3                              518.67                           642.20
# 4                              518.67                           642.46
# ...                               ...                              ...
# 16591                          518.67                           643.04
# 16592                          518.67                           642.47
# 16593                          518.67                           642.70
# 16594                          518.67                           642.19
# 16595                          518.67                           643.19
#
#        Total temperature at HPC outlet  Total temperature at LPT outlet  \
# 0                              1581.93                          1396.93
# 1                              1584.86                          1398.90
# 2                              1581.78                          1391.92
# 3                              1584.53                          1395.34
# 4                              1589.03                          1395.86
# ...                                ...                              ...
# 16591                          1594.99                          1411.28
# 16592                          1591.27                          1417.64
# 16593                          1593.81                          1412.70
# 16594                          1595.63                          1406.58
# 16595                          1592.54                          1407.20
#
#        Pressure at fan inlet  ...  Ratio of fuel flow to Ps30  \
# 0                      14.62  ...                      521.89
# 1                      14.62  ...                      521.85
# 2                      14.62  ...                      522.10
# 3                      14.62  ...                      522.45
# 4                      14.62  ...                      521.91
# ...                      ...  ...                         ...
# 16591                  14.62  ...                      529.23
# 16592                  14.62  ...                      529.27
# 16593                  14.62  ...                      529.48
# 16594                  14.62  ...                      529.39
# 16595                  14.62  ...                      529.59
#
#        Corrected fan speed  Corrected core speed  Bypass Ratio  \
# 0                  2387.94               8133.48        8.3760
# 1                  2388.01               8137.44        8.4062
# 2                  2387.94               8138.25        8.3553
# 3                  2387.96               8137.07        8.3709
# 4                  2387.97               8134.20        8.4146
# ...                    ...                   ...           ...
# 16591              2388.24               8162.24        8.2939
# 16592              2388.26               8163.24        8.3247
# 16593              2388.28               8162.12        8.3264
# 16594              2388.33               8164.20        8.2908
# 16595              2388.29               8169.24        8.3191
#
#        Burner fuel-air ratio  Bleed Enthalpy  Demanded fan speed  \
# 0                       0.03             391                2388
# 1                       0.03             391                2388
# 2                       0.03             391                2388
# 3                       0.03             392                2388
# 4                       0.03             391                2388
# ...                      ...             ...                 ...
# 16591                   0.03             395                2388
# 16592                   0.03             394                2388
# 16593                   0.03             394                2388
# 16594                   0.03             395                2388
# 16595                   0.03             392                2388
#
#        Demanded corrected fan speed  HPT coolant bleed  LPT coolant bleed
# 0                             100.0              39.07            23.4468
# 1                             100.0              39.04            23.4807
# 2                             100.0              39.10            23.4244
# 3                             100.0              38.97            23.4782
# 4                             100.0              39.09            23.3950
# ...                             ...                ...                ...
# 16591                         100.0              39.40            23.4949
# 16592                         100.0              39.42            23.6011
# 16593                         100.0              39.43            23.5482
# 16594                         100.0              39.40            23.6687
# 16595                         100.0              39.41            23.6536
#
# [16596 rows x 26 columns]

# %%
rul = pd.read_csv((file_path3) , sep='\s+', header = None, names = ['RUL'])

# %%
rul
# Out:
#     RUL
# 0    44
# 1    51
# 2    27
# 3   120
# 4   101
# ..  ...
# 95  113
# 96  123
# 97   17
# 98    8
# 99   28
#
# [100 rows x 1 columns]

# %%
rul['RUL'].describe()
# Out:
# count    100.000000
# mean      75.320000
# std       41.604166
# min        6.000000
# 25%       43.250000
# 50%       77.500000
# 75%      115.000000
# max      145.000000
# Name: RUL, dtype: float64

# %%
train3.describe().T
# Out:
#                                    count         mean           std  \
# engine                           24720.0    48.631877  2.934899e+01
# cycles                           24720.0   139.077063  9.884668e+01
# setting1                         24720.0    -0.000024  2.193545e-03
# setting2                         24720.0     0.000005  2.940429e-04
# setting3                         24720.0   100.000000  0.000000e+00
# Total temperature at fan inlet   24720.0   518.670000  6.684921e-11
# Total temperature at LPC outlet  24720.0   642.457858  5.230311e-01
# Total temperature at HPC outlet  24720.0  1588.079175  6.810418e+00
# Total temperature at LPT outlet  24720.0  1404.471212  9.773178e+00
# Pressure at fan inlet            24720.0    14.620000  3.602525e-12
# Total pressure in bypass-duct    24720.0    21.595841  1.811600e-02
# Total pressure at HPC outlet     24720.0   555.143808  3.437343e+00
# Physical fan speed               24720.0  2388.071555  1.582849e-01
# Physical core speed              24720.0  9064.110809  1.998029e+01
# Engine pressure ratio (P50/P2)   24720.0     1.301232  3.484849e-03
# Static pressure at HPC outlet    24720.0    47.415707  3.000742e-01
# Ratio of fuel flow to Ps30       24720.0   523.050873  3.255314e+00
# Corrected fan speed              24720.0  2388.071643  1.581207e-01
# Corrected core speed             24720.0  8144.202916  1.650412e+01
# Bypass Ratio                     24720.0     8.396176  6.051161e-02
# Burner fuel-air ratio            24720.0     0.030000  1.750371e-14
# Bleed Enthalpy                   24720.0   392.566545  1.761459e+00
# Demanded fan speed               24720.0  2388.000000  0.000000e+00
# Demanded corrected fan speed     24720.0   100.000000  0.000000e+00
# HPT coolant bleed                24720.0    38.988552  2.488647e-01
# LPT coolant bleed                24720.0    23.393024  1.492338e-01
#
#                                        min        25%        50%        75%  \
# engine                              1.0000    23.0000    47.0000    74.0000
# cycles                              1.0000    62.0000   124.0000   191.0000
# setting1                           -0.0086    -0.0015    -0.0000     0.0015
# setting2                           -0.0006    -0.0002    -0.0000     0.0003
# setting3                          100.0000   100.0000   100.0000   100.0000
# Total temperature at fan inlet    518.6700   518.6700   518.6700   518.6700
# Total temperature at LPC outlet   640.8400   642.0800   642.4000   642.7900
# Total temperature at HPC outlet  1564.3000  1583.2800  1587.5200  1592.4125
# Total temperature at LPT outlet  1377.0600  1397.1875  1402.9100  1410.6000
# Pressure at fan inlet              14.6200    14.6200    14.6200    14.6200
# Total pressure in bypass-duct      21.4500    21.5800    21.6000    21.6100
# Total pressure at HPC outlet      549.6100   553.1100   554.0500   556.0400
# Physical fan speed               2386.9000  2388.0000  2388.0700  2388.1400
# Physical core speed              9017.9800  9051.9200  9060.0100  9070.0925
# Engine pressure ratio (P50/P2)      1.2900     1.3000     1.3000     1.3000
# Static pressure at HPC outlet      46.6900    47.1900    47.3600    47.6000
# Ratio of fuel flow to Ps30        517.7700   521.1500   521.9800   523.8400
# Corrected fan speed              2386.9300  2388.0100  2388.0700  2388.1400
# Corrected core speed             8099.6800  8134.5100  8141.2000  8149.2300
# Bypass Ratio                        8.1563     8.3606     8.3983     8.4370
# Burner fuel-air ratio               0.0300     0.0300     0.0300     0.0300
# Bleed Enthalpy                    388.0000   391.0000   392.0000   394.0000
# Demanded fan speed               2388.0000  2388.0000  2388.0000  2388.0000
# Demanded corrected fan speed      100.0000   100.0000   100.0000   100.0000
# HPT coolant bleed                  38.1700    38.8300    38.9900    39.1400
# LPT coolant bleed                  22.8726    23.2962    23.3916    23.4833
#
#                                        max
# engine                            100.0000
# cycles                            525.0000
# setting1                            0.0086
# setting2                            0.0007
# setting3                          100.0000
# Total temperature at fan inlet    518.6700
# Total temperature at LPC outlet   645.1100
# Total temperature at HPC outlet  1615.3900
# Total temperature at LPT outlet  1441.1600
# Pressure at fan inlet              14.6200
# Total pressure in bypass-duct      21.6100
# Total pressure at HPC outlet      570.4900
# Physical fan speed               2388.6000
# Physical core speed              9234.3500
# Engine pressure ratio (P50/P2)      1.3200
# Static pressure at HPC outlet      48.4400
# Ratio of fuel flow to Ps30        537.4000
# Corrected fan speed              2388.6100
# Corrected core speed             8290.5500
# Bypass Ratio                        8.5705
# Burner fuel-air ratio               0.0300
# Bleed Enthalpy                    399.0000
# Demanded fan speed               2388.0000
# Demanded corrected fan speed      100.0000
# HPT coolant bleed                  39.8500
# LPT coolant bleed                  23.9505

# %%
test3.describe().T
# Out:
#                                    count         mean           std  \
# engine                           16596.0    51.887383  2.985352e+01
# cycles                           16596.0   105.999518  8.328690e+01
# setting1                         16596.0    -0.000017  2.201359e-03
# setting2                         16596.0    -0.000004  2.941945e-04
# setting3                         16596.0   100.000000  0.000000e+00
# Total temperature at fan inlet   16596.0   518.670000  6.309810e-11
# Total temperature at LPC outlet  16596.0   642.267980  4.188497e-01
# Total temperature at HPC outlet  16596.0  1585.608286  5.538577e+00
# Total temperature at LPT outlet  16596.0  1400.567943  7.150365e+00
# Pressure at fan inlet            16596.0    14.620000  3.089178e-12
# Total pressure in bypass-duct    16596.0    21.594215  1.649689e-02
# Total pressure at HPC outlet     16596.0   554.555216  2.236182e+00
# Physical fan speed               16596.0  2388.021318  1.502066e-01
# Physical core speed              16596.0  9056.274490  1.200179e+01
# Engine pressure ratio (P50/P2)   16596.0     1.300456  2.120888e-03
# Static pressure at HPC outlet    16596.0    47.290751  2.172649e-01
# Ratio of fuel flow to Ps30       16596.0   522.466597  2.113488e+00
# Corrected fan speed              16596.0  2388.021013  1.497706e-01
# Corrected core speed             16596.0  8138.326536  9.974272e+00
# Bypass Ratio                     16596.0     8.395036  4.133206e-02
# Burner fuel-air ratio            16596.0     0.030000  1.271591e-14
# Bleed Enthalpy                   16596.0   391.900036  1.390909e+00
# Demanded fan speed               16596.0  2388.000000  0.000000e+00
# Demanded corrected fan speed     16596.0   100.000000  0.000000e+00
# HPT coolant bleed                16596.0    38.996889  1.748174e-01
# LPT coolant bleed                16596.0    23.398909  1.054154e-01
#
#                                        min        25%        50%          75%  \
# engine                              1.0000    24.0000    52.0000    78.000000
# cycles                              1.0000    42.0000    87.0000   149.000000
# setting1                           -0.0087    -0.0015     0.0000     0.001500
# setting2                           -0.0006    -0.0003     0.0000     0.000300
# setting3                          100.0000   100.0000   100.0000   100.000000
# Total temperature at fan inlet    518.6700   518.6700   518.6700   518.670000
# Total temperature at LPC outlet   640.9100   641.9800   642.2400   642.550000
# Total temperature at HPC outlet  1565.0800  1581.8475  1585.4600  1589.240000
# Total temperature at LPT outlet  1379.3800  1395.4400  1399.8400  1405.230000
# Pressure at fan inlet              14.6200    14.6200    14.6200    14.620000
# Total pressure in bypass-duct      21.5500    21.5800    21.6000    21.610000
# Total pressure at HPC outlet      549.5500   553.3500   554.0900   555.190000
# Physical fan speed               2386.9300  2387.9800  2388.0400  2388.090000
# Physical core speed              9023.0100  9048.8300  9055.0700  9061.970000
# Engine pressure ratio (P50/P2)      1.2900     1.3000     1.3000     1.300000
# Static pressure at HPC outlet      46.6500    47.1300    47.2600    47.440000
# Ratio of fuel flow to Ps30        517.6700   521.3700   522.0100   523.000000
# Corrected fan speed              2386.9400  2387.9800  2388.0400  2388.090000
# Corrected core speed             8105.4500  8132.3100  8137.5950  8143.190000
# Bypass Ratio                        8.1980     8.3687     8.3951     8.424125
# Burner fuel-air ratio               0.0300     0.0300     0.0300     0.030000
# Bleed Enthalpy                    387.0000   391.0000   392.0000   393.000000
# Demanded fan speed               2388.0000  2388.0000  2388.0000  2388.000000
# Demanded corrected fan speed      100.0000   100.0000   100.0000   100.000000
# HPT coolant bleed                  38.3200    38.8800    39.0000    39.110000
# LPT coolant bleed                  23.0390    23.3275    23.3985    23.465400
#
#                                        max
# engine                            100.0000
# cycles                            475.0000
# setting1                            0.0083
# setting2                            0.0006
# setting3                          100.0000
# Total temperature at fan inlet    518.6700
# Total temperature at LPC outlet   644.0300
# Total temperature at HPC outlet  1607.1300
# Total temperature at LPT outlet  1430.2100
# Pressure at fan inlet              14.6200
# Total pressure in bypass-duct      21.6100
# Total pressure at HPC outlet      567.6800
# Physical fan speed               2388.5000
# Physical core speed              9119.4700
# Engine pressure ratio (P50/P2)      1.3100
# Static pressure at HPC outlet      48.2500
# Ratio of fuel flow to Ps30        535.6300
# Corrected fan speed              2388.5300
# Corrected core speed             8191.3800
# Bypass Ratio                        8.5328
# Burner fuel-air ratio               0.0300
# Bleed Enthalpy                    398.0000
# Demanded fan speed               2388.0000
# Demanded corrected fan speed      100.0000
# HPT coolant bleed                  39.7500
# LPT coolant bleed                  23.8496

# %%
train3.hist(bins=50, figsize=(18,16))
plt.show()

# %%
test3.hist(bins=50, figsize=(18,16))
plt.show()

# %%
sens_const_values = ['setting3', 'Total temperature at fan inlet', 'Pressure at fan inlet', 'Engine pressure ratio (P50/P2)', 'Burner fuel-air ratio', 'Demanded fan speed', 'Demanded corrected fan speed']

# %%
train3.drop(sens_const_values, axis=1, inplace=True)

# %%
test3.drop(sens_const_values, axis=1, inplace=True)

# %%
train3
# Out:
#        engine  cycles  setting1  setting2  Total temperature at LPC outlet  \
# 0           1       1   -0.0005    0.0004                           642.36
# 1           1       2    0.0008   -0.0003                           642.50
# 2           1       3   -0.0014   -0.0002                           642.18
# 3           1       4   -0.0020    0.0001                           642.92
# 4           1       5    0.0016    0.0000                           641.68
# ...       ...     ...       ...       ...                              ...
# 24715     100     148   -0.0016   -0.0003                           643.78
# 24716     100     149    0.0034   -0.0003                           643.29
# 24717     100     150   -0.0016    0.0004                           643.84
# 24718     100     151   -0.0023    0.0004                           643.94
# 24719     100     152    0.0000    0.0003                           643.64
#
#        Total temperature at HPC outlet  Total temperature at LPT outlet  \
# 0                              1583.23                          1396.84
# 1                              1584.69                          1396.89
# 2                              1582.35                          1405.61
# 3                              1585.61                          1392.27
# 4                              1588.63                          1397.65
# ...                                ...                              ...
# 24715                          1596.01                          1424.11
# 24716                          1596.38                          1429.14
# 24717                          1604.53                          1431.41
# 24718                          1597.56                          1426.57
# 24719                          1599.04                          1436.06
#
#        Total pressure in bypass-duct  Total pressure at HPC outlet  \
# 0                              21.61                        553.97
# 1                              21.61                        554.55
# 2                              21.61                        554.43
# 3                              21.61                        555.21
# 4                              21.61                        554.74
# ...                              ...                           ...
# 24715                          21.61                        551.86
# 24716                          21.61                        551.86
# 24717                          21.61                        551.30
# 24718                          21.61                        550.69
# 24719                          21.61                        550.96
#
#        Physical fan speed  Physical core speed  Static pressure at HPC outlet  \
# 0                 2387.96              9062.17                          47.30
# 1                 2388.00              9061.78                          47.23
# 2                 2388.03              9070.23                          47.22
# 3                 2388.00              9064.57                          47.24
# 4                 2388.04              9076.14                          47.15
# ...                   ...                  ...                            ...
# 24715             2388.25              9070.82                          48.27
# 24716             2388.23              9064.60                          48.13
# 24717             2388.25              9063.45                          48.18
# 24718             2388.26              9062.22                          48.05
# 24719             2388.26              9066.52                          48.12
#
#        Ratio of fuel flow to Ps30  Corrected fan speed  Corrected core speed  \
# 0                          522.31              2388.01               8145.32
# 1                          522.42              2388.03               8152.85
# 2                          522.03              2388.00               8150.17
# 3                          522.49              2388.08               8146.56
# 4                          522.58              2388.03               8147.80
# ...                           ...                  ...                   ...
# 24715                      519.66              2388.30               8138.08
# 24716                      519.91              2388.28               8144.36
# 24717                      519.44              2388.24               8135.95
# 24718                      520.01              2388.26               8141.24
# 24719                      519.48              2388.24               8136.98
#
#        Bypass Ratio  Bleed Enthalpy  HPT coolant bleed  LPT coolant bleed
# 0            8.4246             391              39.11            23.3537
# 1            8.4403             392              38.99            23.4491
# 2            8.3901             391              38.85            23.3669
# 3            8.3878             392              38.96            23.2951
# 4            8.3869             392              39.14            23.4583
# ...             ...             ...                ...                ...
# 24715        8.5036             394              38.44            22.9631
# 24716        8.5174             395              38.50            22.9746
# 24717        8.5223             396              38.39            23.0682
# 24718        8.5148             395              38.31            23.0753
# 24719        8.5150             396              38.56            23.0847
#
# [24720 rows x 19 columns]

# %%
train3.isnull().sum()
# Out:
# engine                             0
# cycles                             0
# setting1                           0
# setting2                           0
# Total temperature at LPC outlet    0
# Total temperature at HPC outlet    0
# Total temperature at LPT outlet    0
# Total pressure in bypass-duct      0
# Total pressure at HPC outlet       0
# Physical fan speed                 0
# Physical core speed                0
# Static pressure at HPC outlet      0
# Ratio of fuel flow to Ps30         0
# Corrected fan speed                0
# Corrected core speed               0
# Bypass Ratio                       0
# Bleed Enthalpy                     0
# HPT coolant bleed                  0
# LPT coolant bleed                  0
# dtype: int64

# %%
test3.isnull().sum()
# Out:
# engine                             0
# cycles                             0
# setting1                           0
# setting2                           0
# Total temperature at LPC outlet    0
# Total temperature at HPC outlet    0
# Total temperature at LPT outlet    0
# Total pressure in bypass-duct      0
# Total pressure at HPC outlet       0
# Physical fan speed                 0
# Physical core speed                0
# Static pressure at HPC outlet      0
# Ratio of fuel flow to Ps30         0
# Corrected fan speed                0
# Corrected core speed               0
# Bypass Ratio                       0
# Bleed Enthalpy                     0
# HPT coolant bleed                  0
# LPT coolant bleed                  0
# dtype: int64

# %%
test3
# Out:
#        engine  cycles  setting1  setting2  Total temperature at LPC outlet  \
# 0           1       1   -0.0017   -0.0004                           641.94
# 1           1       2    0.0006   -0.0002                           642.02
# 2           1       3    0.0014   -0.0003                           641.68
# 3           1       4    0.0027    0.0001                           642.20
# 4           1       5   -0.0001    0.0001                           642.46
# ...       ...     ...       ...       ...                              ...
# 16591     100     243    0.0011   -0.0003                           643.04
# 16592     100     244   -0.0024    0.0002                           642.47
# 16593     100     245   -0.0053    0.0002                           642.70
# 16594     100     246   -0.0006    0.0001                           642.19
# 16595     100     247    0.0023    0.0004                           643.19
#
#        Total temperature at HPC outlet  Total temperature at LPT outlet  \
# 0                              1581.93                          1396.93
# 1                              1584.86                          1398.90
# 2                              1581.78                          1391.92
# 3                              1584.53                          1395.34
# 4                              1589.03                          1395.86
# ...                                ...                              ...
# 16591                          1594.99                          1411.28
# 16592                          1591.27                          1417.64
# 16593                          1593.81                          1412.70
# 16594                          1595.63                          1406.58
# 16595                          1592.54                          1407.20
#
#        Total pressure in bypass-duct  Total pressure at HPC outlet  \
# 0                              21.58                        554.56
# 1                              21.58                        554.10
# 2                              21.58                        554.41
# 3                              21.59                        554.58
# 4                              21.58                        554.16
# ...                              ...                           ...
# 16591                          21.58                        561.21
# 16592                          21.58                        561.02
# 16593                          21.58                        561.16
# 16594                          21.58                        562.66
# 16595                          21.58                        562.32
#
#        Physical fan speed  Physical core speed  Static pressure at HPC outlet  \
# 0                 2387.93              9048.65                          47.09
# 1                 2387.94              9046.53                          47.08
# 2                 2387.97              9054.92                          47.15
# 3                 2387.94              9055.04                          47.26
# 4                 2388.01              9048.59                          46.94
# ...                   ...                  ...                            ...
# 16591             2388.24              9088.31                          47.61
# 16592             2388.29              9085.35                          47.75
# 16593             2388.23              9084.29                          47.60
# 16594             2388.24              9092.52                          47.69
# 16595             2388.30              9094.27                          47.71
#
#        Ratio of fuel flow to Ps30  Corrected fan speed  Corrected core speed  \
# 0                          521.89              2387.94               8133.48
# 1                          521.85              2388.01               8137.44
# 2                          522.10              2387.94               8138.25
# 3                          522.45              2387.96               8137.07
# 4                          521.91              2387.97               8134.20
# ...                           ...                  ...                   ...
# 16591                      529.23              2388.24               8162.24
# 16592                      529.27              2388.26               8163.24
# 16593                      529.48              2388.28               8162.12
# 16594                      529.39              2388.33               8164.20
# 16595                      529.59              2388.29               8169.24
#
#        Bypass Ratio  Bleed Enthalpy  HPT coolant bleed  LPT coolant bleed
# 0            8.3760             391              39.07            23.4468
# 1            8.4062             391              39.04            23.4807
# 2            8.3553             391              39.10            23.4244
# 3            8.3709             392              38.97            23.4782
# 4            8.4146             391              39.09            23.3950
# ...             ...             ...                ...                ...
# 16591        8.2939             395              39.40            23.4949
# 16592        8.3247             394              39.42            23.6011
# 16593        8.3264             394              39.43            23.5482
# 16594        8.2908             395              39.40            23.6687
# 16595        8.3191             392              39.41            23.6536
#
# [16596 rows x 19 columns]

# %%
# ============================
# 2. Add RUL labels
# ============================

# --- TRAIN ---
rul_train3 = train3.groupby("engine")["cycles"].max().reset_index()
rul_train3.columns = ["engine", "max_cycles"]

train3 = train3.merge(rul_train3, on="engine", how="left")
train3["RUL"] = train3["max_cycles"] - train3["cycles"]
train3.drop("max_cycles", axis=1, inplace=True)

# %%
# Test
rul_test3 = test3.groupby("engine")["cycles"].max().reset_index()
rul_test3.columns = ["engine", "last_cycles"]
rul_test3 = rul_test3.merge(rul, left_index=True, right_index=True)
rul_test3["max_cycles"] = rul_test3["last_cycles"] + rul_test3["RUL"]
test3 = test3.merge(rul_test3[["engine", "max_cycles"]], on="engine", how="left")
test3["RUL"] = test3["max_cycles"] - test3["cycles"]
test3.drop("max_cycles", axis=1, inplace=True)

# %%
train3
# Out:
#        engine  cycles  setting1  setting2  Total temperature at LPC outlet  \
# 0           1       1   -0.0005    0.0004                           642.36
# 1           1       2    0.0008   -0.0003                           642.50
# 2           1       3   -0.0014   -0.0002                           642.18
# 3           1       4   -0.0020    0.0001                           642.92
# 4           1       5    0.0016    0.0000                           641.68
# ...       ...     ...       ...       ...                              ...
# 24715     100     148   -0.0016   -0.0003                           643.78
# 24716     100     149    0.0034   -0.0003                           643.29
# 24717     100     150   -0.0016    0.0004                           643.84
# 24718     100     151   -0.0023    0.0004                           643.94
# 24719     100     152    0.0000    0.0003                           643.64
#
#        Total temperature at HPC outlet  Total temperature at LPT outlet  \
# 0                              1583.23                          1396.84
# 1                              1584.69                          1396.89
# 2                              1582.35                          1405.61
# 3                              1585.61                          1392.27
# 4                              1588.63                          1397.65
# ...                                ...                              ...
# 24715                          1596.01                          1424.11
# 24716                          1596.38                          1429.14
# 24717                          1604.53                          1431.41
# 24718                          1597.56                          1426.57
# 24719                          1599.04                          1436.06
#
#        Total pressure in bypass-duct  Total pressure at HPC outlet  \
# 0                              21.61                        553.97
# 1                              21.61                        554.55
# 2                              21.61                        554.43
# 3                              21.61                        555.21
# 4                              21.61                        554.74
# ...                              ...                           ...
# 24715                          21.61                        551.86
# 24716                          21.61                        551.86
# 24717                          21.61                        551.30
# 24718                          21.61                        550.69
# 24719                          21.61                        550.96
#
#        Physical fan speed  Physical core speed  Static pressure at HPC outlet  \
# 0                 2387.96              9062.17                          47.30
# 1                 2388.00              9061.78                          47.23
# 2                 2388.03              9070.23                          47.22
# 3                 2388.00              9064.57                          47.24
# 4                 2388.04              9076.14                          47.15
# ...                   ...                  ...                            ...
# 24715             2388.25              9070.82                          48.27
# 24716             2388.23              9064.60                          48.13
# 24717             2388.25              9063.45                          48.18
# 24718             2388.26              9062.22                          48.05
# 24719             2388.26              9066.52                          48.12
#
#        Ratio of fuel flow to Ps30  Corrected fan speed  Corrected core speed  \
# 0                          522.31              2388.01               8145.32
# 1                          522.42              2388.03               8152.85
# 2                          522.03              2388.00               8150.17
# 3                          522.49              2388.08               8146.56
# 4                          522.58              2388.03               8147.80
# ...                           ...                  ...                   ...
# 24715                      519.66              2388.30               8138.08
# 24716                      519.91              2388.28               8144.36
# 24717                      519.44              2388.24               8135.95
# 24718                      520.01              2388.26               8141.24
# 24719                      519.48              2388.24               8136.98
#
#        Bypass Ratio  Bleed Enthalpy  HPT coolant bleed  LPT coolant bleed  RUL
# 0            8.4246             391              39.11            23.3537  258
# 1            8.4403             392              38.99            23.4491  257
# 2            8.3901             391              38.85            23.3669  256
# 3            8.3878             392              38.96            23.2951  255
# 4            8.3869             392              39.14            23.4583  254
# ...             ...             ...                ...                ...  ...
# 24715        8.5036             394              38.44            22.9631    4
# 24716        8.5174             395              38.50            22.9746    3
# 24717        8.5223             396              38.39            23.0682    2
# 24718        8.5148             395              38.31            23.0753    1
# 24719        8.5150             396              38.56            23.0847    0
#
# [24720 rows x 20 columns]

# %%
plt.rcParams['figure.figsize'] = 8,40
plt.rcParams['font.size'] = 8
plt.rcParams['lines.linewidth'] = 0.1

plot_items = list(train3.columns)[1:-1]
fig, ax = plt.subplots(len(plot_items),sharex = True)
ax[0].invert_xaxis()

engines= list(train3['engine'].unique())

for engine in engines [20:40]:
  for i, item in enumerate(plot_items):
    f = sns.lineplot(data = train3[train3['engine']==engine], x='RUL', y=item, color='green',ax=ax[i])

# %%
RUL_cap = 130
train3["RUL"] = np.where(train3["RUL"] > RUL_cap, RUL_cap, train3["RUL"])
test3["RUL"] = np.where(test3["RUL"] > RUL_cap, RUL_cap, test3["RUL"])

# %%
train3
# Out:
#        engine  cycles  setting1  setting2  Total temperature at LPC outlet  \
# 0           1       1   -0.0005    0.0004                           642.36
# 1           1       2    0.0008   -0.0003                           642.50
# 2           1       3   -0.0014   -0.0002                           642.18
# 3           1       4   -0.0020    0.0001                           642.92
# 4           1       5    0.0016    0.0000                           641.68
# ...       ...     ...       ...       ...                              ...
# 24715     100     148   -0.0016   -0.0003                           643.78
# 24716     100     149    0.0034   -0.0003                           643.29
# 24717     100     150   -0.0016    0.0004                           643.84
# 24718     100     151   -0.0023    0.0004                           643.94
# 24719     100     152    0.0000    0.0003                           643.64
#
#        Total temperature at HPC outlet  Total temperature at LPT outlet  \
# 0                              1583.23                          1396.84
# 1                              1584.69                          1396.89
# 2                              1582.35                          1405.61
# 3                              1585.61                          1392.27
# 4                              1588.63                          1397.65
# ...                                ...                              ...
# 24715                          1596.01                          1424.11
# 24716                          1596.38                          1429.14
# 24717                          1604.53                          1431.41
# 24718                          1597.56                          1426.57
# 24719                          1599.04                          1436.06
#
#        Total pressure in bypass-duct  Total pressure at HPC outlet  \
# 0                              21.61                        553.97
# 1                              21.61                        554.55
# 2                              21.61                        554.43
# 3                              21.61                        555.21
# 4                              21.61                        554.74
# ...                              ...                           ...
# 24715                          21.61                        551.86
# 24716                          21.61                        551.86
# 24717                          21.61                        551.30
# 24718                          21.61                        550.69
# 24719                          21.61                        550.96
#
#        Physical fan speed  Physical core speed  Static pressure at HPC outlet  \
# 0                 2387.96              9062.17                          47.30
# 1                 2388.00              9061.78                          47.23
# 2                 2388.03              9070.23                          47.22
# 3                 2388.00              9064.57                          47.24
# 4                 2388.04              9076.14                          47.15
# ...                   ...                  ...                            ...
# 24715             2388.25              9070.82                          48.27
# 24716             2388.23              9064.60                          48.13
# 24717             2388.25              9063.45                          48.18
# 24718             2388.26              9062.22                          48.05
# 24719             2388.26              9066.52                          48.12
#
#        Ratio of fuel flow to Ps30  Corrected fan speed  Corrected core speed  \
# 0                          522.31              2388.01               8145.32
# 1                          522.42              2388.03               8152.85
# 2                          522.03              2388.00               8150.17
# 3                          522.49              2388.08               8146.56
# 4                          522.58              2388.03               8147.80
# ...                           ...                  ...                   ...
# 24715                      519.66              2388.30               8138.08
# 24716                      519.91              2388.28               8144.36
# 24717                      519.44              2388.24               8135.95
# 24718                      520.01              2388.26               8141.24
# 24719                      519.48              2388.24               8136.98
#
#        Bypass Ratio  Bleed Enthalpy  HPT coolant bleed  LPT coolant bleed  RUL
# 0            8.4246             391              39.11            23.3537  125
# 1            8.4403             392              38.99            23.4491  125
# 2            8.3901             391              38.85            23.3669  125
# 3            8.3878             392              38.96            23.2951  125
# 4            8.3869             392              39.14            23.4583  125
# ...             ...             ...                ...                ...  ...
# 24715        8.5036             394              38.44            22.9631    4
# 24716        8.5174             395              38.50            22.9746    3
# 24717        8.5223             396              38.39            23.0682    2
# 24718        8.5148             395              38.31            23.0753    1
# 24719        8.5150             396              38.56            23.0847    0
#
# [24720 rows x 20 columns]

# %%
plt.rcParams['figure.figsize'] = 8,40
plt.rcParams['font.size'] = 8
plt.rcParams['lines.linewidth'] = 0.1

plot_items = list(train3.columns)[1:-1]
fig, ax = plt.subplots(len(plot_items),sharex = True)
ax[0].invert_xaxis()

engines= list(train3['engine'].unique())

for engine in engines [20:40]:
  for i, item in enumerate(plot_items):
    f = sns.lineplot(data = train3[train3['engine']==engine], x='RUL', y=item, color='green',ax=ax[i])

# %%
corr = train3.corr()
f, ax = plt.subplots(figsize=(16,16))
dataplot = sns.heatmap(corr, cmap="YlGnBu", annot=True )

# %%
# Based on literature, these sensors are useful for FD001
useful_sensors = ['setting1', 'setting2', 'Total temperature at LPC outlet', 'Total temperature at HPC outlet', 'Total temperature at LPT outlet', 'Total pressure in bypass-duct', 'Total pressure at HPC outlet', 'Physical fan speed', 'Physical core speed', 'Static pressure at HPC outlet', 'Ratio of fuel flow to Ps30', 'Corrected fan speed', 'Corrected core speed', 'Bypass Ratio',  'Bleed Enthalpy', 'HPT coolant bleed', 'LPT coolant bleed']
feature_cols = useful_sensors

# %%
scaler = MinMaxScaler()
train3[feature_cols] = scaler.fit_transform(train3[feature_cols])
test3[feature_cols] = scaler.transform(test3[feature_cols])

# %%
def create_sequences(df, window_size=30):
    X, y = [], []
    for eng in df["engine"].unique():  # replaced 'unit' with 'engine'
        eng_df = df[df["engine"] == eng]
        eng_features = eng_df[feature_cols].values
        eng_rul = eng_df["RUL"].values
        for i in range(len(eng_df) - window_size + 1):
            X.append(eng_features[i:i+window_size])
            y.append(eng_rul[i+window_size-1])  # predict RUL at end of window
    return np.array(X), np.array(y)

# Example usage
window_size = 30
X_train, y_train = create_sequences(train3, window_size)
X_test, y_test = create_sequences(test3, window_size)

print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_test:", X_test.shape, "y_test:", y_test.shape)
# Out:
# X_train: (21820, 30, 17) y_train: (21820,)
# X_test: (13696, 30, 17) y_test: (13696,)

# %%
from tensorflow.keras.layers import Bidirectional, Input, Layer
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K

# %%
# ============================
# Custom Attention Layer
# ============================
class Attention(Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1),
                                 initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1),
                                 initializer="zeros")
        super(Attention, self).build(input_shape)

    def call(self, x):
        # Compute attention scores
        e = K.tanh(K.dot(x, self.W) + self.b)
        e = K.squeeze(e, axis=-1)
        alpha = K.softmax(e)
        alpha = K.expand_dims(alpha, axis=-1)
        context = x * alpha
        return K.sum(context, axis=1)

# %%
# ============================
# Build BiLSTM + Attention model
# ============================
def build_bilstm_attention(window_size, n_features):
    inputs = Input(shape=(window_size, n_features))
    x = Bidirectional(LSTM(64, return_sequences=True))(inputs)
    x = Dropout(0.3)(x)
    x = Bidirectional(LSTM(32, return_sequences=True))(x)
    x = Dropout(0.3)(x)
    x = Attention()(x)   # attention over time steps
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    outputs = Dense(1)(x)
    model = Model(inputs, outputs)
    model.compile(optimizer="adam", loss="mse")
    return model

# %%
# ============================
# Train BiLSTM+Attention
# ============================
model = build_bilstm_attention(window_size, len(feature_cols))

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    verbose=1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 5684.8037 - val_loss: 1723.4010
# Epoch 2/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 1851.1884 - val_loss: 1722.3887
# Epoch 3/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 1847.8086 - val_loss: 1722.3134
# Epoch 4/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1770.7970 - val_loss: 320.4150
# Epoch 5/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 458.2047 - val_loss: 312.3864
# Epoch 6/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 444.1544 - val_loss: 292.3375
# Epoch 7/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 422.0622 - val_loss: 314.0737
# Epoch 8/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 422.6706 - val_loss: 252.0792
# Epoch 9/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 381.3374 - val_loss: 236.5175
# Epoch 10/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 383.8762 - val_loss: 225.4485
# Epoch 11/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 377.6461 - val_loss: 228.2972
# Epoch 12/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 334.9091 - val_loss: 206.8219
# Epoch 13/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 340.3278 - val_loss: 234.5852
# Epoch 14/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 328.3843 - val_loss: 247.2983
# Epoch 15/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 318.8714 - val_loss: 185.9905
# Epoch 16/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 310.2762 - val_loss: 205.8114
# Epoch 17/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 310.7345 - val_loss: 154.4912
# Epoch 18/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 294.4701 - val_loss: 155.4625
# Epoch 19/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 282.9811 - val_loss: 139.4126
# Epoch 20/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 278.6152 - val_loss: 205.0002
# Epoch 21/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 290.0672 - val_loss: 164.3326
# Epoch 22/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 265.0514 - val_loss: 167.8805
# Epoch 23/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 276.4636 - val_loss: 164.7870
# Epoch 24/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 261.1371 - val_loss: 176.2002
# Epoch 25/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 279.4764 - val_loss: 146.9329
# Epoch 26/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 267.0684 - val_loss: 145.3156
# Epoch 27/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 267.0497 - val_loss: 140.6969
# Epoch 28/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 255.2198 - val_loss: 179.9705
# Epoch 29/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 259.5931 - val_loss: 131.4069
# Epoch 30/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 254.3218 - val_loss: 137.3239
# Epoch 31/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 248.2995 - val_loss: 149.6458
# Epoch 32/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 259.0374 - val_loss: 135.0872
# Epoch 33/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 248.8020 - val_loss: 127.7216
# Epoch 34/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 239.7215 - val_loss: 171.7001
# Epoch 35/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 264.9565 - val_loss: 134.4698
# Epoch 36/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 250.5461 - val_loss: 140.9521
# Epoch 37/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 248.8615 - val_loss: 143.8033
# Epoch 38/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 245.7834 - val_loss: 151.8495
# Epoch 39/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 244.9019 - val_loss: 133.7006
# Epoch 40/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 249.4548 - val_loss: 146.2223
# Epoch 41/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 234.2918 - val_loss: 131.2870
# Epoch 42/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 236.7083 - val_loss: 168.9536
# Epoch 43/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 237.3258 - val_loss: 138.7724

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], color="#1f77b4", linewidth=2.5, label="Train Loss")      # deep blue
plt.plot(history.history["val_loss"], color="#d62728", linewidth=2.5, label="Validation Loss")  # deep red

plt.xlabel("Epochs", fontsize=12, fontweight='bold')
plt.ylabel("MSE Loss", fontsize=12, fontweight='bold')
plt.title("Training Curve - BiLSTM + Attention (FD003)", fontsize=13, fontweight='bold')

plt.legend(frameon=False, fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ============================
# Evaluate
# ============================
y_pred = model.predict(X_test).flatten()
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"\n📊 BiLSTM+Attention on FD003 → RMSE={rmse:.2f}, R²={r2:.4f}")
# Out:
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
#
# 📊 BiLSTM+Attention on FD003 → RMSE=13.12, R²=0.7867

# %%
# ============================
# 6. Evaluation
# ============================
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print(f"✅ Test RMSE: {rmse:.2f}")
print(f"✅ Test R²: {r2:.4f}")

# ============================
# 7. Plot Predictions vs True
# ============================
plt.figure(figsize=(10,5))
plt.scatter(range(len(y_test)), y_test, label="True RUL", s=10)
plt.scatter(range(len(y_pred)), y_pred, label="Predicted RUL", s=10, alpha=0.7)
plt.title("RUL Prediction - FD003")
plt.xlabel("Test samples")
plt.ylabel("Remaining Useful Life (cycles)")
plt.legend()
plt.show()
# Out:
# ✅ Test RMSE: 13.12
# ✅ Test R²: 0.7867
